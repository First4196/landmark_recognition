# %% [markdown]
# # Split Train Test Valid

# %%
import numpy as np 
import pandas as pd

# %%
data = pd.read_csv('data/data.csv')
data
# Out:
#        index                                                url  label
# 0          0  https://upload.wikimedia.org/wikipedia/commons...      0
# 1          1  https://upload.wikimedia.org/wikipedia/commons...      0
# 2          2  https://upload.wikimedia.org/wikipedia/commons...      0
# 3          3  https://upload.wikimedia.org/wikipedia/commons...      0
# 4          4  https://upload.wikimedia.org/wikipedia/commons...      0
# ...      ...                                                ...    ...
# 91613  91613  https://upload.wikimedia.org/wikipedia/commons...     99
# 91614  91614  https://upload.wikimedia.org/wikipedia/commons...     99
# 91615  91615  https://upload.wikimedia.org/wikipedia/commons...     99
# 91616  91616  https://upload.wikimedia.org/wikipedia/commons...     99
# 91617  91617  https://upload.wikimedia.org/wikipedia/commons...     99
#
# [91618 rows x 3 columns]

# %%
data['label'].nunique()
# Out:
# 100

# %%
train_list = []
test_list = []
valid_list = []

for i in data['label'].unique():
    class_data = data[data['label'] == i]
    train, valid, test = np.split(class_data.sample(frac=1), [int(.8*len(class_data)), int(.9*len(class_data))])
    train_list.append(train)
    test_list.append(test)
    valid_list.append(valid)

# %%
train = pd.concat(train_list)
train
# Out:
#        index                                                url  label
# 1273    1273  https://upload.wikimedia.org/wikipedia/commons...      0
# 1914    1914  https://upload.wikimedia.org/wikipedia/commons...      0
# 2409    2409  https://upload.wikimedia.org/wikipedia/commons...      0
# 97        97  https://upload.wikimedia.org/wikipedia/commons...      0
# 2030    2030  https://upload.wikimedia.org/wikipedia/commons...      0
# ...      ...                                                ...    ...
# 91612  91612  https://upload.wikimedia.org/wikipedia/commons...     99
# 91261  91261  https://upload.wikimedia.org/wikipedia/commons...     99
# 91607  91607  https://upload.wikimedia.org/wikipedia/commons...     99
# 91319  91319  https://upload.wikimedia.org/wikipedia/commons...     99
# 91384  91384  https://upload.wikimedia.org/wikipedia/commons...     99
#
# [73252 rows x 3 columns]

# %%
test = pd.concat(test_list)
test
# Out:
#        index                                                url  label
# 908      908  https://upload.wikimedia.org/wikipedia/commons...      0
# 1485    1485  https://upload.wikimedia.org/wikipedia/commons...      0
# 365      365  https://upload.wikimedia.org/wikipedia/commons...      0
# 496      496  https://upload.wikimedia.org/wikipedia/commons...      0
# 1072    1072  https://upload.wikimedia.org/wikipedia/commons...      0
# ...      ...                                                ...    ...
# 91514  91514  https://upload.wikimedia.org/wikipedia/commons...     99
# 91487  91487  https://upload.wikimedia.org/wikipedia/commons...     99
# 91287  91287  https://upload.wikimedia.org/wikipedia/commons...     99
# 91409  91409  https://upload.wikimedia.org/wikipedia/commons...     99
# 91565  91565  https://upload.wikimedia.org/wikipedia/commons...     99
#
# [9205 rows x 3 columns]

# %%
valid = pd.concat(valid_list)
valid
# Out:
#        index                                                url  label
# 1048    1048  https://upload.wikimedia.org/wikipedia/commons...      0
# 1556    1556  https://upload.wikimedia.org/wikipedia/commons...      0
# 573      573  https://upload.wikimedia.org/wikipedia/commons...      0
# 1300    1300  https://upload.wikimedia.org/wikipedia/commons...      0
# 1295    1295  https://upload.wikimedia.org/wikipedia/commons...      0
# ...      ...                                                ...    ...
# 91577  91577  https://upload.wikimedia.org/wikipedia/commons...     99
# 91482  91482  https://upload.wikimedia.org/wikipedia/commons...     99
# 91553  91553  https://upload.wikimedia.org/wikipedia/commons...     99
# 91483  91483  https://upload.wikimedia.org/wikipedia/commons...     99
# 91179  91179  https://upload.wikimedia.org/wikipedia/commons...     99
#
# [9161 rows x 3 columns]

# %%
train.to_csv("data/train.csv", index = False)
test.to_csv("data/test.csv", index = False)
valid.to_csv("data/valid.csv", index = False)
